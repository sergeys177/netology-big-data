# %% [markdown]
# <a href="https://colab.research.google.com/github/sergeys177/netology-big-data/blob/master/hw1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = pd.read_csv('abalone.csv')
data.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
print(data.Length.mean())
print(data.Diameter.median())
print(data.Height.min())
print(data.Rings.max())
# Out:
# 0.5239920995930099
# 0.425
# 0.0
# 29

# %%
data.Diameter.hist(bins=100)

# %%
data.Length.value_counts(bins=5).plot.bar()

# %%
import matplotlib.pyplot as plt

# %%
plt.figure();
data.Rings.hist(bins=100)

# %%
plt.figure()
data.Length.plot()

# %%
data.groupby('Sex').Length.min().plot.bar()

# %%
from pandas.plotting import andrews_curves

data = pd.read_csv('abalone.csv')
plt.figure()
andrews_curves(data, 'Sex')

# %%
from pandas.plotting import radviz
data = pd.read_csv('abalone.csv')
plt.figure()
radviz(data, 'Sex')
